# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_fi = pd.read_csv("FI_values_cv_only_pw.csv")

# %%
data_fi
# Out:
#     Unnamed: 0     first    second     third
# 0            0  0.016531  0.017508  0.013449
# 1            1  0.018328  0.021173  0.015345
# 2            2  0.018474  0.018173  0.016063
# 3            3  0.019275  0.020587  0.020431
# 4            4  0.030024  0.026851  0.019179
# 5            5  0.020640  0.018125  0.013937
# 6            6  0.021889  0.023674  0.017196
# 7            7  0.023305  0.019826  0.014728
# 8            8  0.020052  0.018856  0.016731
# 9            9  0.018990  0.022455  0.015269
# 10          10  0.018980  0.021789  0.017715
# 11          11  0.017811  0.017596  0.021165
# 12          12  0.012274  0.013615  0.010143
# 13          13  0.015221  0.018367  0.012584
# 14          14  0.012892  0.014495  0.012532
# 15          15  0.018237  0.021823  0.019478
# 16          16  0.019253  0.021053  0.020124
# 17          17  0.017765  0.020445  0.016698
# 18          18  0.019021  0.019578  0.014782
# 19          19  0.019588  0.018086  0.015304
# 20          20  0.026452  0.030141  0.021372
# 21          21  0.020525  0.020741  0.021650
# 22          22  0.021962  0.024004  0.023129
# 23          23  0.019622  0.017969  0.013503
# 24          24  0.020370  0.018516  0.015373
# 25          25  0.018568  0.019063  0.016330
# 26          26  0.018069  0.018254  0.018006
# 27          27  0.047977  0.038924  0.061990
# 28          28  0.023745  0.025667  0.027774
# 29          29  0.019853  0.019621  0.014714
# 30          30  0.028126  0.023544  0.029159
# 31          31  0.018719  0.018472  0.018892
# 32          32  0.018266  0.020872  0.012018
# 33          33  0.029250  0.027072  0.031218
# 34          34  0.019454  0.020273  0.017163
# 35          35  0.021199  0.023988  0.022742
# 36          36  0.028675  0.031485  0.045653
# 37          37  0.021191  0.030268  0.062197
# 38          38  0.038453  0.029773  0.030861
# 39          39  0.057131  0.044716  0.090612
# 40          40  0.016023  0.017292  0.011618
# 41          41  0.021313  0.022970  0.020558
# 42          42  0.019706  0.018426  0.016477
# 43          43  0.022205  0.021919  0.017505
# 44          44  0.024595  0.021956  0.016631

# %%
data_fi.shape
# Out:
# (45, 4)

# %%
data_fi = data_fi.drop(['Unnamed: 0'], axis=1)

# %%
data_fi
# Out:
#        first    second     third
# 0   0.016531  0.017508  0.013449
# 1   0.018328  0.021173  0.015345
# 2   0.018474  0.018173  0.016063
# 3   0.019275  0.020587  0.020431
# 4   0.030024  0.026851  0.019179
# 5   0.020640  0.018125  0.013937
# 6   0.021889  0.023674  0.017196
# 7   0.023305  0.019826  0.014728
# 8   0.020052  0.018856  0.016731
# 9   0.018990  0.022455  0.015269
# 10  0.018980  0.021789  0.017715
# 11  0.017811  0.017596  0.021165
# 12  0.012274  0.013615  0.010143
# 13  0.015221  0.018367  0.012584
# 14  0.012892  0.014495  0.012532
# 15  0.018237  0.021823  0.019478
# 16  0.019253  0.021053  0.020124
# 17  0.017765  0.020445  0.016698
# 18  0.019021  0.019578  0.014782
# 19  0.019588  0.018086  0.015304
# 20  0.026452  0.030141  0.021372
# 21  0.020525  0.020741  0.021650
# 22  0.021962  0.024004  0.023129
# 23  0.019622  0.017969  0.013503
# 24  0.020370  0.018516  0.015373
# 25  0.018568  0.019063  0.016330
# 26  0.018069  0.018254  0.018006
# 27  0.047977  0.038924  0.061990
# 28  0.023745  0.025667  0.027774
# 29  0.019853  0.019621  0.014714
# 30  0.028126  0.023544  0.029159
# 31  0.018719  0.018472  0.018892
# 32  0.018266  0.020872  0.012018
# 33  0.029250  0.027072  0.031218
# 34  0.019454  0.020273  0.017163
# 35  0.021199  0.023988  0.022742
# 36  0.028675  0.031485  0.045653
# 37  0.021191  0.030268  0.062197
# 38  0.038453  0.029773  0.030861
# 39  0.057131  0.044716  0.090612
# 40  0.016023  0.017292  0.011618
# 41  0.021313  0.022970  0.020558
# 42  0.019706  0.018426  0.016477
# 43  0.022205  0.021919  0.017505
# 44  0.024595  0.021956  0.016631

# %%
data_fi['mean'] = round(data_fi.mean(axis=1),3)

# %%
data_fi
# Out:
#        first    second     third   mean
# 0   0.016531  0.017508  0.013449  0.016
# 1   0.018328  0.021173  0.015345  0.018
# 2   0.018474  0.018173  0.016063  0.018
# 3   0.019275  0.020587  0.020431  0.020
# 4   0.030024  0.026851  0.019179  0.025
# 5   0.020640  0.018125  0.013937  0.018
# 6   0.021889  0.023674  0.017196  0.021
# 7   0.023305  0.019826  0.014728  0.019
# 8   0.020052  0.018856  0.016731  0.019
# 9   0.018990  0.022455  0.015269  0.019
# 10  0.018980  0.021789  0.017715  0.019
# 11  0.017811  0.017596  0.021165  0.019
# 12  0.012274  0.013615  0.010143  0.012
# 13  0.015221  0.018367  0.012584  0.015
# 14  0.012892  0.014495  0.012532  0.013
# 15  0.018237  0.021823  0.019478  0.020
# 16  0.019253  0.021053  0.020124  0.020
# 17  0.017765  0.020445  0.016698  0.018
# 18  0.019021  0.019578  0.014782  0.018
# 19  0.019588  0.018086  0.015304  0.018
# 20  0.026452  0.030141  0.021372  0.026
# 21  0.020525  0.020741  0.021650  0.021
# 22  0.021962  0.024004  0.023129  0.023
# 23  0.019622  0.017969  0.013503  0.017
# 24  0.020370  0.018516  0.015373  0.018
# 25  0.018568  0.019063  0.016330  0.018
# 26  0.018069  0.018254  0.018006  0.018
# 27  0.047977  0.038924  0.061990  0.050
# 28  0.023745  0.025667  0.027774  0.026
# 29  0.019853  0.019621  0.014714  0.018
# 30  0.028126  0.023544  0.029159  0.027
# 31  0.018719  0.018472  0.018892  0.019
# 32  0.018266  0.020872  0.012018  0.017
# 33  0.029250  0.027072  0.031218  0.029
# 34  0.019454  0.020273  0.017163  0.019
# 35  0.021199  0.023988  0.022742  0.023
# 36  0.028675  0.031485  0.045653  0.035
# 37  0.021191  0.030268  0.062197  0.038
# 38  0.038453  0.029773  0.030861  0.033
# 39  0.057131  0.044716  0.090612  0.064
# 40  0.016023  0.017292  0.011618  0.015
# 41  0.021313  0.022970  0.020558  0.022
# 42  0.019706  0.018426  0.016477  0.018
# 43  0.022205  0.021919  0.017505  0.021
# 44  0.024595  0.021956  0.016631  0.021

# %%
data_for_names = pd.read_csv("cv_x_under.csv")

# %%
data_for_names = data_for_names.iloc[:, 1:46]

# %%
data_for_names
# Out:
#              T  delta_t        CT   prop_s    t_sys    t_dia  t_ratio  \
# 0      0.80270  0.12973  0.202700  0.25253  0.28378  0.51892  0.54688
# 1      0.80270  0.14595  0.210810  0.26263  0.30811  0.49459  0.62295
# 2      0.76154  0.12308  0.200000  0.26263  0.28462  0.47692  0.59677
# 3      0.94286  0.31429  0.095238  0.10101  0.35238  0.59048  0.59677
# 4      0.71566  0.22410  0.231330  0.32323  0.42651  0.28916  1.47500
# ...        ...      ...       ...      ...      ...      ...      ...
# 20597  0.71566  0.11566  0.180720  0.25253  0.25301  0.46265  0.54688
# 20598  1.06070  0.19286  0.225000  0.21212  0.36429  0.69643  0.52308
# 20599  0.90000  0.20000  0.218180  0.24242  0.32727  0.57273  0.57143
# 20600  0.95806  0.13548  0.261290  0.27273  0.35806  0.60000  0.59677
# 20601  1.16470  0.14118  0.282350  0.24242  0.38824  0.77647  0.50000
#
#        prop_delta_t  t_p1in_dia  t_p2in_dia  ...    e_div_amp       AGI  \
# 0           0.16162     0.17027     0.12973  ...  328175.6225 -0.581240
# 1           0.18182     0.18649     0.14595  ...  210854.4495 -0.036414
# 2           0.16162     0.16154     0.12308  ...  437918.2404 -0.512490
# 3           0.33333     0.27619     0.16190  ...  935901.7033 -1.636000
# 4           0.31313     0.36867     0.12289  ...  400551.6764 -1.623400
# ...             ...         ...         ...  ...          ...       ...
# 20597       0.16162     0.15904     0.11566  ...  331371.7349  0.192230
# 20598       0.18182     0.22500     0.19286  ...  167381.7759 -0.039851
# 20599       0.22222     0.22727     0.20000  ...  101260.3893  0.025371
# 20600       0.14141     0.20323     0.13548  ...  213453.2526 -0.080812
# 20601       0.12121     0.22353     0.14118  ...   88455.8215 -0.166350
#
#        AGI_inf   AGI_mod  slope_b_c  slope_b_d     IPAD         k  CT_div_ht  \
# 0     -0.93115 -0.404140     7.5894    4.78220  0.91751 -0.000009   0.115829
# 1     -0.82459  0.120030     4.7214    2.29460  0.30697 -0.000011   0.126994
# 2     -1.04480 -0.266490     8.6320    4.34310  0.66480 -0.000009   0.114286
# 3     -1.65250 -1.215400    23.9125    4.97640  0.22734 -0.000007   0.059154
# 4     -2.63430 -0.885460    16.8424    3.02460 -1.04270 -0.000016   0.137696
# ...        ...       ...        ...        ...      ...       ...        ...
# 20597 -0.74456  0.390710     1.9984    1.05600  0.77552 -0.000010   0.102682
# 20598 -0.81405  0.131850     2.9779    2.97790  0.67657 -0.000013   0.133929
# 20599 -0.79665  0.111180     3.6646    3.66460  0.40755 -0.000012   0.143539
# 20600 -0.82018  0.135320     5.7284    0.59547  0.39544 -0.000013   0.148460
# 20601 -0.73480 -0.066326     5.6695    1.42200  0.68930 -0.000014   0.162738
#
#               SI
# 0      13.489555
# 1      11.373758
# 2      14.218395
# 3       5.122657
# 4       7.496653
# ...          ...
# 20597  15.217015
# 20598   8.710982
# 20599   7.600000
# 20600  12.990847
# 20601  12.289276
#
# [20602 rows x 45 columns]

# %%
data_for_names.columns
# Out:
# Index(['T', 'delta_t', 'CT', 'prop_s', 't_sys', 't_dia', 't_ratio',
#        'prop_delta_t', 't_p1in_dia', 't_p2in_dia', 't_b_c', 't_b_d',
#        'pulse_amp', 'pulse_amp_p1', 'pulse_amp_p2', 'AP', 'AI', 'dia_amp',
#        'RI', 'RI_p1', 'RI_p2', 'ratio_p2_p1', 'A1', 'A2', 'IPA', 'ms',
#        'ms_div_amp', 'b_div_a', 'c_div_a', 'd_div_a', 'e_div_a', 'a_div_amp',
#        'b_div_amp', 'c_div_amp', 'd_div_amp', 'e_div_amp', 'AGI', 'AGI_inf',
#        'AGI_mod', 'slope_b_c', 'slope_b_d', 'IPAD', 'k', 'CT_div_ht', 'SI'],
#       dtype='object')

# %%
df_scores = pd.DataFrame(data_fi['mean'])
df_columns = pd.DataFrame(data_for_names.columns)

feature_scores = pd.concat([df_columns, df_scores], axis =1)
feature_scores.columns = ['Feature_Name', 'Score']

# %%
feature_scores
# Out:
#     Feature_Name  Score
# 0              T  0.016
# 1        delta_t  0.018
# 2             CT  0.018
# 3         prop_s  0.020
# 4          t_sys  0.025
# 5          t_dia  0.018
# 6        t_ratio  0.021
# 7   prop_delta_t  0.019
# 8     t_p1in_dia  0.019
# 9     t_p2in_dia  0.019
# 10         t_b_c  0.019
# 11         t_b_d  0.019
# 12     pulse_amp  0.012
# 13  pulse_amp_p1  0.015
# 14  pulse_amp_p2  0.013
# 15            AP  0.020
# 16            AI  0.020
# 17       dia_amp  0.018
# 18            RI  0.018
# 19         RI_p1  0.018
# 20         RI_p2  0.026
# 21   ratio_p2_p1  0.021
# 22            A1  0.023
# 23            A2  0.017
# 24           IPA  0.018
# 25            ms  0.018
# 26    ms_div_amp  0.018
# 27       b_div_a  0.050
# 28       c_div_a  0.026
# 29       d_div_a  0.018
# 30       e_div_a  0.027
# 31     a_div_amp  0.019
# 32     b_div_amp  0.017
# 33     c_div_amp  0.029
# 34     d_div_amp  0.019
# 35     e_div_amp  0.023
# 36           AGI  0.035
# 37       AGI_inf  0.038
# 38       AGI_mod  0.033
# 39     slope_b_c  0.064
# 40     slope_b_d  0.015
# 41          IPAD  0.022
# 42             k  0.018
# 43     CT_div_ht  0.021
# 44            SI  0.021

# %%
# ordering

data_use = feature_scores.nlargest(45, 'Score')

# %%
data_use
# Out:
#     Feature_Name  Score
# 39     slope_b_c  0.064
# 27       b_div_a  0.050
# 37       AGI_inf  0.038
# 36           AGI  0.035
# 38       AGI_mod  0.033
# 33     c_div_amp  0.029
# 30       e_div_a  0.027
# 20         RI_p2  0.026
# 28       c_div_a  0.026
# 4          t_sys  0.025
# 22            A1  0.023
# 35     e_div_amp  0.023
# 41          IPAD  0.022
# 43     CT_div_ht  0.021
# 21   ratio_p2_p1  0.021
# 44            SI  0.021
# 6        t_ratio  0.021
# 16            AI  0.020
# 3         prop_s  0.020
# 15            AP  0.020
# 31     a_div_amp  0.019
# 7   prop_delta_t  0.019
# 8     t_p1in_dia  0.019
# 9     t_p2in_dia  0.019
# 34     d_div_amp  0.019
# 10         t_b_c  0.019
# 11         t_b_d  0.019
# 1        delta_t  0.018
# 18            RI  0.018
# 29       d_div_a  0.018
# 17       dia_amp  0.018
# 26    ms_div_amp  0.018
# 25            ms  0.018
# 24           IPA  0.018
# 2             CT  0.018
# 42             k  0.018
# 19         RI_p1  0.018
# 5          t_dia  0.018
# 32     b_div_amp  0.017
# 23            A2  0.017
# 0              T  0.016
# 40     slope_b_d  0.015
# 13  pulse_amp_p1  0.015
# 14  pulse_amp_p2  0.013
# 12     pulse_amp  0.012

# %%
data_use.to_csv("feature_imp_only_pw_ordered.csv")

# %%
data_use_15 = data_use.iloc[:15]

# %%
data_use_15
# Out:
#    Feature_Name  Score
# 39    slope_b_c  0.064
# 27      b_div_a  0.050
# 37      AGI_inf  0.038
# 36          AGI  0.035
# 38      AGI_mod  0.033
# 33    c_div_amp  0.029
# 30      e_div_a  0.027
# 20        RI_p2  0.026
# 28      c_div_a  0.026
# 4         t_sys  0.025
# 22           A1  0.023
# 35    e_div_amp  0.023
# 41         IPAD  0.022
# 43    CT_div_ht  0.021
# 21  ratio_p2_p1  0.021

# %%
plotting_names = data_use_15['Feature_Name']
plotting_values = data_use_15['Score']

fig = plt.figure(figsize = (8, 4))
plt.bar(plotting_names, plotting_values, color ='c',
        width = 0.8)
plt.xlabel("Features")
plt.xticks(rotation = 90)
plt.ylabel("Importance values")
plt.title("Feature Importance for PW features for CVD")
plt.show()
